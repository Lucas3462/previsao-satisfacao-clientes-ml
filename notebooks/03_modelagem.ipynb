# %% [markdown]
# # 03 - Modelagem
#
# **Integrantes:** Alan Ribeiro do Carmo (RA 10428496), Jean Pazzini Domingues (RA 10428555) e Wendell Rodrigues da Costa (RA 10420319).
#
# **Docente/orientador:** Leandro Zerbinatti (leandro.zerbinatti@mackenzie.br).
#
# **Síntese:** divisão estratificada, construção e treinamento dos três modelos obrigatórios em pipelines.
#
# **Histórico:** 2026-09-15 | GitHub Copilot | Atualização da modelagem conforme especificação da disciplina.
#
# Treina os três modelos obrigatórios com divisão estratificada e pipelines que encapsulam o pré-processamento.

# %%
from pathlib import Path
import sys
from sklearn.model_selection import train_test_split
ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(ROOT))
from src.data_loader import load_dataset, validate_and_create_target, split_features_target
from src.preprocessing import make_pipelines
data, _ = validate_and_create_target(load_dataset(ROOT / 'Data' / 'dataset_satisfacao_atendimento.csv'))
X, y = split_features_target(data)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)
models = make_pipelines(42)
for name, model in models.items():
    model.fit(X_train, y_train)
    print(name, 'treinado')
# Out:
# Logistic Regression treinado
# Decision Tree treinado
# Random Forest treinado
